# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
print(html_text)

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
job=soup.find('li',class_='clearfix job-bx wht-shd-bx')
company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')

print(company_name)
# Out:
# SuryaInformaticsSolutionsPvt.Ltd.

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
job=soup.find('li',class_='clearfix job-bx wht-shd-bx')
company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
skills=job.find('span',class_='srp-skills').text.replace(' ','')

print(company_name)  
print(skills)
# Out:
# SuryaInformaticsSolutionsPvt.Ltd.
#
#
#
# python,webtechnologies,linux,mobile,mysql,angularjs,javascript

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
job=soup.find('li',class_='clearfix job-bx wht-shd-bx')
company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
skills=job.find('span',class_='srp-skills').text.replace(' ','')

print(f'''
Company name: {company_name}
Required skills: {skills}
''')
# Out:
# Company name:
# SuryaInformaticsSolutionsPvt.Ltd.
#
#
# Required skills:
# python,webtechnologies,linux,mobile,mysql,angularjs,javascript

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
job=soup.find('li',class_='clearfix job-bx wht-shd-bx')
company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
skills=job.find('span',class_='srp-skills').text.replace(' ','')
published_date=job.find('span',class_='sim-posted').span.text

print(f'''
Company name: {company_name}
Required skills: {skills}
Published date: {published_date}
''')
# Out:
# Company name:
# SuryaInformaticsSolutionsPvt.Ltd.
#
#
# Required skills:
# python,webtechnologies,linux,mobile,mysql,angularjs,javascript
#
#
# Published date: Posted few days ago

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

for job in jobs:
    company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
    skills=job.find('span',class_='srp-skills').text.replace(' ','')
    published_date=job.find('span',class_='sim-posted').span.text

    print(f'''
    Company name: {company_name}
    Required skills: {skills}
    Published date: {published_date}
    ''')
    
    print("")
# Out:
#     Company name:
# SuryaInformaticsSolutionsPvt.Ltd.
#
#
#     Required skills:
# python,webtechnologies,linux,mobile,mysql,angularjs,javascript
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# MACKENZIEMODERNITSOLUTIONSPVTLTD
# (MoreJobs)
#
#     Required skills:
#
# DataScience,Matplotlib,Git,Panda,Aws,Numpy,PythonScripting,BusinessProcess,Testing
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# RESEARCHDEVELOPERS
# (MoreJobs)
#
#     Required skills:
# python,research,pythonprogrammer,MachineLearning,PatternRecognition,ImageProcessing,DigitalImage,SignalProcessing,ElectronicCircuits,NetworkAnalysis
#
#
#     Published date:
# Work from Home
#
#
#
#
#     Company name:
# PerfiosSoftware
#
#
#     Required skills:
# python,java,scala
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# MUSIKAAR
#
#
#     Required skills:
# python,problemsolving,django,mysql
#
#
#     Published date: Posted 3 days ago
#
#
#
#     Company name:
# TriadssTechSolutions
#
#
#     Required skills:
# python,django,html5,javascript
#
#
#     Published date: Posted 6 days ago
#
#
#
#     Company name:
# IvanInfotechPvt.Ltd.
#
#
#     Required skills:
#
# rest,python,security,debugging
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# MaxgenTechnologies
# (MoreJobs)
#
#     Required skills:
#
# gujarat,python,winterinternship
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# qualitythought
#
#
#     Required skills:
#
# rest,python,django,informationtechnology
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# eastindiasecuritiesltd.
#
#
#     Required skills:
# python,hadoop,machinelearning
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# TandAHRSolutions
#
#
#     Required skills:
# python,git,django
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# JobsLoConsultants
#
#
#     Required skills:
# python,linux,windows,sql
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# CONNECTING2WORK
#
#
#     Required skills:
# python,storage,django,testingtools,debugging
#
#
#     Published date: Posted 5 days ago
#
#
#
#     Company name:
# WingGlobalITServices
#
#
#     Required skills:
#
# springboot,python,java,django,jpa,hibernate
#
#
#     Published date: Posted 5 days ago
#
#
#
#     Company name:
# TandAHRSolutions
#
#
#     Required skills:
# Python,Django,Flask
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# arttechnologyandsoftwareindiapvtltd
#
#
#     Required skills:
#
# rest,python,database,django,api
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# sjainventures
#
#
#     Required skills:
# python,webdeveloper,webservices
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# systango
#
#
#     Required skills:
# python,django,javascript,webprogramming
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# RouteMobileLimited
#
#
#     Required skills:
# python,django,postgresql,mysql,docker
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# youngmindstechnologysolutionspvtltd
#
#
#     Required skills:
# python,html5,storage,javascript,security,django
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# PolarisConsulting&ServicesLtd
#
#
#     Required skills:
# python,django,apache,devops
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#     Required skills:
# python,webtechnologies,webtechnologies
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#     Required skills:
# python,django,html5,javascript
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# AnanthaCyberTechPvtLimited
#
#
#     Required skills:
# python,c,c,informationtechnology
#
#
#     Published date: Posted few days ago
#
#
#
#     Company name:
# DREAMAJAXTECHNOLOGIES
#
#
#     Required skills:
# python,django,api,sql,nosql
#
#
#     Published date: Posted few days ago

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

for job in jobs:
    published_date=job.find('span',class_='sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_='srp-skills').text.replace(' ','')

        print(f'''
        Company name: {company_name}
        Required skills: {skills}
        Published date: {published_date}
        ''')

        print("")
# Out:
#         Company name:
# SuryaInformaticsSolutionsPvt.Ltd.
#
#
#         Required skills:
# python,webtechnologies,linux,mobile,mysql,angularjs,javascript
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# MACKENZIEMODERNITSOLUTIONSPVTLTD
# (MoreJobs)
#
#         Required skills:
#
# DataScience,Matplotlib,Git,Panda,Aws,Numpy,PythonScripting,BusinessProcess,Testing
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# PerfiosSoftware
#
#
#         Required skills:
# python,java,scala
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# IvanInfotechPvt.Ltd.
#
#
#         Required skills:
#
# rest,python,security,debugging
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# MaxgenTechnologies
# (MoreJobs)
#
#         Required skills:
#
# gujarat,python,winterinternship
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# qualitythought
#
#
#         Required skills:
#
# rest,python,django,informationtechnology
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# eastindiasecuritiesltd.
#
#
#         Required skills:
# python,hadoop,machinelearning
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# TandAHRSolutions
#
#
#         Required skills:
# python,git,django
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# JobsLoConsultants
#
#
#         Required skills:
# python,linux,windows,sql
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# TandAHRSolutions
#
#
#         Required skills:
# Python,Django,Flask
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# arttechnologyandsoftwareindiapvtltd
#
#
#         Required skills:
#
# rest,python,database,django,api
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# sjainventures
#
#
#         Required skills:
# python,webdeveloper,webservices
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# systango
#
#
#         Required skills:
# python,django,javascript,webprogramming
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# RouteMobileLimited
#
#
#         Required skills:
# python,django,postgresql,mysql,docker
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# youngmindstechnologysolutionspvtltd
#
#
#         Required skills:
# python,html5,storage,javascript,security,django
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# PolarisConsulting&ServicesLtd
#
#
#         Required skills:
# python,django,apache,devops
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#         Required skills:
# python,webtechnologies,webtechnologies
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#         Required skills:
# python,django,html5,javascript
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# AnanthaCyberTechPvtLimited
#
#
#         Required skills:
# python,c,c,informationtechnology
#
#
#         Published date: Posted few days ago
#
#
#
#         Company name:
# DREAMAJAXTECHNOLOGIES
#
#
#         Required skills:
# python,django,api,sql,nosql
#
#
#         Published date: Posted few days ago

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

for job in jobs:
    published_date=job.find('span',class_='sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_='srp-skills').text.replace(' ','')
        print(f'Company name: {company_name.strip()}')
        print(f'Required Skills: {skills.strip()}')
        print('')
# Out:
# Company name: SuryaInformaticsSolutionsPvt.Ltd.
# Required Skills: python,webtechnologies,linux,mobile,mysql,angularjs,javascript
#
# Company name: MACKENZIEMODERNITSOLUTIONSPVTLTD
# (MoreJobs)
# Required Skills: DataScience,Matplotlib,Git,Panda,Aws,Numpy,PythonScripting,BusinessProcess,Testing
#
# Company name: PerfiosSoftware
# Required Skills: python,java,scala
#
# Company name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
#
# Company name: MaxgenTechnologies
# (MoreJobs)
# Required Skills: gujarat,python,winterinternship
#
# Company name: qualitythought
# Required Skills: rest,python,django,informationtechnology
#
# Company name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
#
# Company name: TandAHRSolutions
# Required Skills: python,git,django
#
# Company name: JobsLoConsultants
# Required Skills: python,linux,windows,sql
#
# Company name: TandAHRSolutions
# Required Skills: Python,Django,Flask
#
# Company name: arttechnologyandsoftwareindiapvtltd
# Required Skills: rest,python,database,django,api
#
# Company name: sjainventures
# Required Skills: python,webdeveloper,webservices
#
# Company name: systango
# Required Skills: python,django,javascript,webprogramming
#
# Company name: RouteMobileLimited
# Required Skills: python,django,postgresql,mysql,docker
#
# Company name: youngmindstechnologysolutionspvtltd
# Required Skills: python,html5,storage,javascript,security,django
#
# Company name: PolarisConsulting&ServicesLtd
# Required Skills: python,django,apache,devops
#
# Company name: APPLYCUPHIRINGSOLUTIONSLLP
# Required Skills: python,webtechnologies,webtechnologies
#
# Company name: APPLYCUPHIRINGSOLUTIONSLLP
# Required Skills: python,django,html5,javascript
#
# Company name: AnanthaCyberTechPvtLimited
# Required Skills: python,c,c,informationtechnology
#
# Company name: DREAMAJAXTECHNOLOGIES
# Required Skills: python,django,api,sql,nosql

# %%
# Out:
# Company name: SuryaInformaticsSolutionsPvt.Ltd.
# Required Skills: python,webtechnologies,linux,mobile,mysql,angularjs,javascript
# More Info: https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: MACKENZIEMODERNITSOLUTIONSPVTLTD
# (MoreJobs)
# Required Skills: DataScience,Matplotlib,Git,Panda,Aws,Numpy,PythonScripting,BusinessProcess,Testing
# More Info: https://www.timesjobs.com/job-detail/python-developer-python-programmer-mackenzie-modern-it-solutions-pvt-ltd-ahmedabad-bengaluru-bangalore-chennai-delhi-delhi-ncr-2-to-7-yrs-jobid-35d7jSW30eZzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: PerfiosSoftware
# Required Skills: python,java,scala
# More Info: https://www.timesjobs.com/job-detail/python-developer-perfios-software-bengaluru-bangalore-5-to-8-yrs-jobid-5GGtzEeKMXxzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
# More Info: https://www.timesjobs.com/job-detail/python-developer-ivan-infotech-pvt-ltd-kolkata-2-to-5-yrs-jobid-1h6sLaqbaBZzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: MaxgenTechnologies
# (MoreJobs)
# Required Skills: gujarat,python,winterinternship
# More Info: https://www.timesjobs.com/job-detail/python-internship-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-pp0__PLUS__Y8dKKxlzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: qualitythought
# Required Skills: rest,python,django,informationtechnology
# More Info: https://www.timesjobs.com/job-detail/python-django-quality-thought-hyderabad-secunderabad-2-to-5-yrs-jobid-A0WJWgCiZSRzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
# More Info: https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-KEkE19WqPbFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: TandAHRSolutions
# Required Skills: python,git,django
# More Info: https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-gurgaon-chandigarh-4-to-6-yrs-jobid-2OM9xzKEDx5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: JobsLoConsultants
# Required Skills: python,linux,windows,sql
# More Info: https://www.timesjobs.com/job-detail/python-developer-jobslo-consultants-indore-2-to-3-yrs-jobid-XP1detWpoa5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: TandAHRSolutions
# Required Skills: Python,Django,Flask
# More Info: https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-mohali-chandigarh-3-to-6-yrs-jobid-hyDozRehVidzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: arttechnologyandsoftwareindiapvtltd
# Required Skills: rest,python,database,django,api
# More Info: https://www.timesjobs.com/job-detail/python-developer-art-technology-and-software-india-pvt-ltd-cochin-kochi-ernakulam-2-to-3-yrs-jobid-M26lxDEd__PLUS__qtzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: sjainventures
# Required Skills: python,webdeveloper,webservices
# More Info: https://www.timesjobs.com/job-detail/python-intern-sjain-ventures-raipur-0-to-3-yrs-jobid-KmspiL9__SLASH__D9hzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: systango
# Required Skills: python,django,javascript,webprogramming
# More Info: https://www.timesjobs.com/job-detail/python-developer-systango-indore-5-to-8-yrs-jobid-YtDomXdajg5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: RouteMobileLimited
# Required Skills: python,django,postgresql,mysql,docker
# More Info: https://www.timesjobs.com/job-detail/python-developers-route-mobile-limited-mumbai-2-to-3-yrs-jobid-XPaQ1HLdzlFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: youngmindstechnologysolutionspvtltd
# Required Skills: python,html5,storage,javascript,security,django
# More Info: https://www.timesjobs.com/job-detail/python-developer-young-minds-technology-solutions-pvt-ltd-tirupati-0-to-3-yrs-jobid-NDA__SLASH__WwOTUCFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: PolarisConsulting&ServicesLtd
# Required Skills: python,django,apache,devops
# More Info: https://www.timesjobs.com/job-detail/python-devops-polaris-consulting-services-ltd-bengaluru-bangalore-0-to-3-yrs-jobid-ksmR1q1a555zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: APPLYCUPHIRINGSOLUTIONSLLP
# Required Skills: python,webtechnologies,webtechnologies
# More Info: https://www.timesjobs.com/job-detail/python-trainer-applycup-hiring-solutions-llp-pune-4-to-6-yrs-jobid-3V1Biww1YVJzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: APPLYCUPHIRINGSOLUTIONSLLP
# Required Skills: python,django,html5,javascript
# More Info: https://www.timesjobs.com/job-detail/python-developer-applycup-hiring-solutions-llp-gandhinagar-2-to-4-yrs-jobid-t8Ti7DllljpzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: AnanthaCyberTechPvtLimited
# Required Skills: python,c,c,informationtechnology
# More Info: https://www.timesjobs.com/job-detail/python-developer-anantha-cyber-tech-pvt-limited-hyderabad-secunderabad-3-to-6-yrs-jobid-QF9wZ4AGuzlzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: DREAMAJAXTECHNOLOGIES
# Required Skills: python,django,api,sql,nosql
# More Info: https://www.timesjobs.com/job-detail/python-developer-dreamajax-technologies-bengaluru-bangalore-4-to-7-yrs-jobid-EWIVCDzRLKBzpSvf__PLUS__uAgZw==&source=srp

# %%
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

for job in jobs:
    published_date=job.find('span',class_='sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_='srp-skills').text.replace(' ','')
        more_info=job.header.h2.a['href']
        print(f'Company name: {company_name.strip()}')
        print(f'Required Skills: {skills.strip()}')
        print(f'More Info: {more_info}')
        print('')
# Out:
# Company name: SuryaInformaticsSolutionsPvt.Ltd.
# Required Skills: python,webtechnologies,linux,mobile,mysql,angularjs,javascript
# More Info: https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: MACKENZIEMODERNITSOLUTIONSPVTLTD
# (MoreJobs)
# Required Skills: DataScience,Matplotlib,Git,Panda,Aws,Numpy,PythonScripting,BusinessProcess,Testing
# More Info: https://www.timesjobs.com/job-detail/python-developer-python-programmer-mackenzie-modern-it-solutions-pvt-ltd-ahmedabad-bengaluru-bangalore-chennai-delhi-delhi-ncr-2-to-7-yrs-jobid-35d7jSW30eZzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: PerfiosSoftware
# Required Skills: python,java,scala
# More Info: https://www.timesjobs.com/job-detail/python-developer-perfios-software-bengaluru-bangalore-5-to-8-yrs-jobid-5GGtzEeKMXxzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
# More Info: https://www.timesjobs.com/job-detail/python-developer-ivan-infotech-pvt-ltd-kolkata-2-to-5-yrs-jobid-1h6sLaqbaBZzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: MaxgenTechnologies
# (MoreJobs)
# Required Skills: gujarat,python,winterinternship
# More Info: https://www.timesjobs.com/job-detail/python-internship-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-pp0__PLUS__Y8dKKxlzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: qualitythought
# Required Skills: rest,python,django,informationtechnology
# More Info: https://www.timesjobs.com/job-detail/python-django-quality-thought-hyderabad-secunderabad-2-to-5-yrs-jobid-A0WJWgCiZSRzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
# More Info: https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-KEkE19WqPbFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: TandAHRSolutions
# Required Skills: python,git,django
# More Info: https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-gurgaon-chandigarh-4-to-6-yrs-jobid-2OM9xzKEDx5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: JobsLoConsultants
# Required Skills: python,linux,windows,sql
# More Info: https://www.timesjobs.com/job-detail/python-developer-jobslo-consultants-indore-2-to-3-yrs-jobid-XP1detWpoa5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: TandAHRSolutions
# Required Skills: Python,Django,Flask
# More Info: https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-mohali-chandigarh-3-to-6-yrs-jobid-hyDozRehVidzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: arttechnologyandsoftwareindiapvtltd
# Required Skills: rest,python,database,django,api
# More Info: https://www.timesjobs.com/job-detail/python-developer-art-technology-and-software-india-pvt-ltd-cochin-kochi-ernakulam-2-to-3-yrs-jobid-M26lxDEd__PLUS__qtzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: sjainventures
# Required Skills: python,webdeveloper,webservices
# More Info: https://www.timesjobs.com/job-detail/python-intern-sjain-ventures-raipur-0-to-3-yrs-jobid-KmspiL9__SLASH__D9hzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: systango
# Required Skills: python,django,javascript,webprogramming
# More Info: https://www.timesjobs.com/job-detail/python-developer-systango-indore-5-to-8-yrs-jobid-YtDomXdajg5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: RouteMobileLimited
# Required Skills: python,django,postgresql,mysql,docker
# More Info: https://www.timesjobs.com/job-detail/python-developers-route-mobile-limited-mumbai-2-to-3-yrs-jobid-XPaQ1HLdzlFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: youngmindstechnologysolutionspvtltd
# Required Skills: python,html5,storage,javascript,security,django
# More Info: https://www.timesjobs.com/job-detail/python-developer-young-minds-technology-solutions-pvt-ltd-tirupati-0-to-3-yrs-jobid-NDA__SLASH__WwOTUCFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: PolarisConsulting&ServicesLtd
# Required Skills: python,django,apache,devops
# More Info: https://www.timesjobs.com/job-detail/python-devops-polaris-consulting-services-ltd-bengaluru-bangalore-0-to-3-yrs-jobid-ksmR1q1a555zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: APPLYCUPHIRINGSOLUTIONSLLP
# Required Skills: python,webtechnologies,webtechnologies
# More Info: https://www.timesjobs.com/job-detail/python-trainer-applycup-hiring-solutions-llp-pune-4-to-6-yrs-jobid-3V1Biww1YVJzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: APPLYCUPHIRINGSOLUTIONSLLP
# Required Skills: python,django,html5,javascript
# More Info: https://www.timesjobs.com/job-detail/python-developer-applycup-hiring-solutions-llp-gandhinagar-2-to-4-yrs-jobid-t8Ti7DllljpzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: AnanthaCyberTechPvtLimited
# Required Skills: python,c,c,informationtechnology
# More Info: https://www.timesjobs.com/job-detail/python-developer-anantha-cyber-tech-pvt-limited-hyderabad-secunderabad-3-to-6-yrs-jobid-QF9wZ4AGuzlzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: DREAMAJAXTECHNOLOGIES
# Required Skills: python,django,api,sql,nosql
# More Info: https://www.timesjobs.com/job-detail/python-developer-dreamajax-technologies-bengaluru-bangalore-4-to-7-yrs-jobid-EWIVCDzRLKBzpSvf__PLUS__uAgZw==&source=srp

# %%
print('Put some skill you are not familiar with')
unfamiliar_skill=input('>')
print(f'Filtering out{unfamiliar_skill}')

html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

for job in jobs:
    published_date=job.find('span',class_='sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_='srp-skills').text.replace(' ','')
        more_info=job.header.h2.a['href']
       
        if unfamiliar_skill not in skills:
            print(f'Company name: {company_name.strip()}')
            print(f'Required Skills: {skills.strip()}')
            print(f'More Info: {more_info}')
            print('')
# Out:
# Put some skill you are not familiar with
# >django
# Filtering outdjango
# Company name: SuryaInformaticsSolutionsPvt.Ltd.
# Required Skills: python,webtechnologies,linux,mobile,mysql,angularjs,javascript
# More Info: https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: MACKENZIEMODERNITSOLUTIONSPVTLTD
# (MoreJobs)
# Required Skills: DataScience,Matplotlib,Git,Panda,Aws,Numpy,PythonScripting,BusinessProcess,Testing
# More Info: https://www.timesjobs.com/job-detail/python-developer-python-programmer-mackenzie-modern-it-solutions-pvt-ltd-ahmedabad-bengaluru-bangalore-chennai-delhi-delhi-ncr-2-to-7-yrs-jobid-35d7jSW30eZzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: PerfiosSoftware
# Required Skills: python,java,scala
# More Info: https://www.timesjobs.com/job-detail/python-developer-perfios-software-bengaluru-bangalore-5-to-8-yrs-jobid-5GGtzEeKMXxzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
# More Info: https://www.timesjobs.com/job-detail/python-developer-ivan-infotech-pvt-ltd-kolkata-2-to-5-yrs-jobid-1h6sLaqbaBZzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: MaxgenTechnologies
# (MoreJobs)
# Required Skills: gujarat,python,winterinternship
# More Info: https://www.timesjobs.com/job-detail/python-internship-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-pp0__PLUS__Y8dKKxlzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
# More Info: https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-KEkE19WqPbFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: JobsLoConsultants
# Required Skills: python,linux,windows,sql
# More Info: https://www.timesjobs.com/job-detail/python-developer-jobslo-consultants-indore-2-to-3-yrs-jobid-XP1detWpoa5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: TandAHRSolutions
# Required Skills: Python,Django,Flask
# More Info: https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-mohali-chandigarh-3-to-6-yrs-jobid-hyDozRehVidzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: sjainventures
# Required Skills: python,webdeveloper,webservices
# More Info: https://www.timesjobs.com/job-detail/python-intern-sjain-ventures-raipur-0-to-3-yrs-jobid-KmspiL9__SLASH__D9hzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: APPLYCUPHIRINGSOLUTIONSLLP
# Required Skills: python,webtechnologies,webtechnologies
# More Info: https://www.timesjobs.com/job-detail/python-trainer-applycup-hiring-solutions-llp-pune-4-to-6-yrs-jobid-3V1Biww1YVJzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: AnanthaCyberTechPvtLimited
# Required Skills: python,c,c,informationtechnology
# More Info: https://www.timesjobs.com/job-detail/python-developer-anantha-cyber-tech-pvt-limited-hyderabad-secunderabad-3-to-6-yrs-jobid-QF9wZ4AGuzlzpSvf__PLUS__uAgZw==&source=srp

# %%
print('Put some skill you are not familiar with')
unfamiliar_skill=input('>')
print(f'Filtering out{unfamiliar_skill}')

html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

for job in jobs:
    published_date=job.find('span',class_='sim-posted').span.text
    if 'few' in published_date:
        company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_='srp-skills').text.replace(' ','')
        more_info=job.header.h2.a['href']
       
        if unfamiliar_skill not in skills:
            print(f'Company name: {company_name.strip()}')
            print(f'Required Skills: {skills.strip()}')
            print(f'More Info: {more_info}')
            print('')
# Out:
# Put some skill you are not familiar with
# >java
# Filtering outjava
# Company name: MACKENZIEMODERNITSOLUTIONSPVTLTD
# (MoreJobs)
# Required Skills: DataScience,Matplotlib,Git,Panda,Aws,Numpy,PythonScripting,BusinessProcess,Testing
# More Info: https://www.timesjobs.com/job-detail/python-developer-python-programmer-mackenzie-modern-it-solutions-pvt-ltd-ahmedabad-bengaluru-bangalore-chennai-delhi-delhi-ncr-2-to-7-yrs-jobid-35d7jSW30eZzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: IvanInfotechPvt.Ltd.
# Required Skills: rest,python,security,debugging
# More Info: https://www.timesjobs.com/job-detail/python-developer-ivan-infotech-pvt-ltd-kolkata-2-to-5-yrs-jobid-1h6sLaqbaBZzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: MaxgenTechnologies
# (MoreJobs)
# Required Skills: gujarat,python,winterinternship
# More Info: https://www.timesjobs.com/job-detail/python-internship-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-pp0__PLUS__Y8dKKxlzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: qualitythought
# Required Skills: rest,python,django,informationtechnology
# More Info: https://www.timesjobs.com/job-detail/python-django-quality-thought-hyderabad-secunderabad-2-to-5-yrs-jobid-A0WJWgCiZSRzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: eastindiasecuritiesltd.
# Required Skills: python,hadoop,machinelearning
# More Info: https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-KEkE19WqPbFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: TandAHRSolutions
# Required Skills: python,git,django
# More Info: https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-gurgaon-chandigarh-4-to-6-yrs-jobid-2OM9xzKEDx5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: JobsLoConsultants
# Required Skills: python,linux,windows,sql
# More Info: https://www.timesjobs.com/job-detail/python-developer-jobslo-consultants-indore-2-to-3-yrs-jobid-XP1detWpoa5zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: TandAHRSolutions
# Required Skills: Python,Django,Flask
# More Info: https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-mohali-chandigarh-3-to-6-yrs-jobid-hyDozRehVidzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: arttechnologyandsoftwareindiapvtltd
# Required Skills: rest,python,database,django,api
# More Info: https://www.timesjobs.com/job-detail/python-developer-art-technology-and-software-india-pvt-ltd-cochin-kochi-ernakulam-2-to-3-yrs-jobid-M26lxDEd__PLUS__qtzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: sjainventures
# Required Skills: python,webdeveloper,webservices
# More Info: https://www.timesjobs.com/job-detail/python-intern-sjain-ventures-raipur-0-to-3-yrs-jobid-KmspiL9__SLASH__D9hzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: RouteMobileLimited
# Required Skills: python,django,postgresql,mysql,docker
# More Info: https://www.timesjobs.com/job-detail/python-developers-route-mobile-limited-mumbai-2-to-3-yrs-jobid-XPaQ1HLdzlFzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: PolarisConsulting&ServicesLtd
# Required Skills: python,django,apache,devops
# More Info: https://www.timesjobs.com/job-detail/python-devops-polaris-consulting-services-ltd-bengaluru-bangalore-0-to-3-yrs-jobid-ksmR1q1a555zpSvf__PLUS__uAgZw==&source=srp
#
# Company name: APPLYCUPHIRINGSOLUTIONSLLP
# Required Skills: python,webtechnologies,webtechnologies
# More Info: https://www.timesjobs.com/job-detail/python-trainer-applycup-hiring-solutions-llp-pune-4-to-6-yrs-jobid-3V1Biww1YVJzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: AnanthaCyberTechPvtLimited
# Required Skills: python,c,c,informationtechnology
# More Info: https://www.timesjobs.com/job-detail/python-developer-anantha-cyber-tech-pvt-limited-hyderabad-secunderabad-3-to-6-yrs-jobid-QF9wZ4AGuzlzpSvf__PLUS__uAgZw==&source=srp
#
# Company name: DREAMAJAXTECHNOLOGIES
# Required Skills: python,django,api,sql,nosql
# More Info: https://www.timesjobs.com/job-detail/python-developer-dreamajax-technologies-bengaluru-bangalore-4-to-7-yrs-jobid-EWIVCDzRLKBzpSvf__PLUS__uAgZw==&source=srp

# %%
import time
print('Put some skill you are not familiar with')
unfamiliar_skill=input('>')
print(f'Filtering out{unfamiliar_skill}')

def find_jobs():
    html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
    soup=BeautifulSoup(html_text,'lxml')
    jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

    for job in jobs:
        published_date=job.find('span',class_='sim-posted').span.text
        if 'few' in published_date:
            company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
            skills=job.find('span',class_='srp-skills').text.replace(' ','')
            more_info=job.header.h2.a['href']

            if unfamiliar_skill not in skills:
                print(f'Company name: {company_name.strip()}')
                print(f'Required Skills: {skills.strip()}')
                print(f'More Info: {more_info}')
                print('')
                
    if __name__ == '__main__':
        while True:
            find_jobs()
            time_wait=10
            print(f'Waiting {time_wait}minutes')
            time.sleep(time_wait*60)
            #runs every 10 mins
# Out:
# Put some skill you are not familiar with
# >java
# Filtering outjava

# %%
print('Put some skill you are not familiar with')
unfamiliar_skill=input('>')
print(f'Filtering out{unfamiliar_skill}')

def find_jobs():
    html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
    soup=BeautifulSoup(html_text,'lxml')
    jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

    for index, job in enumerate(jobs):
        published_date=job.find('span',class_='sim-posted').span.text
        if 'few' in published_date:
            company_name=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
            skills=job.find('span',class_='srp-skills').text.replace(' ','')
            more_info=job.header.h2.a['href']

            if unfamiliar_skill not in skills:
                with open(f'posts/{index}.txt','w') as f:
                    
                    f.write(f'Company name: {company_name.strip()}\n')
                    f.write(f'Required Skills: {skills.strip()}\n')
                    f.write(f'More Info: {more_info}\n')
                    print(f'File saved: {index}\n')

    if __name__ == '__main__':
        while True:
            find_jobs()
            time_wait=10
            print(f'Waiting {time_wait}minutes')
            time.sleep(time_wait*60)
            #runs every 10 mins
